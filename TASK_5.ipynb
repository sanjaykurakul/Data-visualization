# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install squarify
import plotly.express as px

df=pd.read_csv('USA_cars_datasets.csv')
print(df)

brand_total_price = df.groupby('brand')['price'].sum().reset_index()
plt.figure(figsize=(18, 12))
squarify.plot(sizes=brand_total_price['price'], label=brand_total_price['brand'], alpha=0.4)
plt.axis('off')
plt.title('Tree Map of Total Price by Brand')
plt.show()

sunburst_data = df.groupby(['brand', 'model']).sum().reset_index()
fig = px.sunburst(sunburst_data, path=['brand', 'model'], values='price', title='Sunburst Display of Total Price by Brand and Model')
fig.show()
# Out:
# Collecting squarify
#   Downloading squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# Downloading squarify-0.4.4-py3-none-any.whl (4.1 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.4
#           Make               Model  \
# 0    Chevrolet                Volt
# 1       Toyota           Prius PHV
# 2       Nissan                Leaf
# 3        Tesla             Model S
# 4         Ford        C-Max Energi
# 5         Ford      Focus Electric
# 6   Mitsubishi              i-MiEV
# 7       Toyota             Rav4 EV
# 8        Honda              Fit EV
# 9         Ford       Fusion Energi
# 10        Fiat                500e
# 11       Smart                  ED
# 12   Chevrolet            Spark EV
# 13       Honda          Accord PHV
# 14     Porsche   Panamera E-Hybrid
# 15    Cadillac                 ELR
# 16         BMW                  i3
# 17    Mercedes          B-Class ED
# 18         BMW                  i8
# 19         Kia             Soul EV
# 20          VW              e-Golf
# 21     Porsche         Cayenne S-E
# 22         BMW        X5 xDrive40e
# 23       Tesla             Model X
# 24     Porsche          918 Spyder
# 25     Hyundai         Sonata PHEV
# 26    Mercedes               S550e
# 27       Volvo                XC90
# 28        Audi    A3 Sprtbk e-tron
# 29       Other               Other
# 30      Toyota         Prius Prime
# 31         BMW                330e
# 32   Chevrolet             Bolt EV
# 33    Mercedes            GLE 550e
# 34    Mercedes               C350e
# 35         BMW                740e
# 36    Chrysler     Pacifica Hybrid
# 37         BMW                530e
# 38       Tesla             Model 3
# 39         Kia         Optima PHEV
# 40       Honda         Clarity BEV
# 41       Honda        Clarity PHEV
# 42       Volvo           XC60 PHEV
# 43        Mini  Countryman SE PHEV
# 44     Hyundai            IONIQ EV
# 45    Cadillac            CT6 PHEV
# 46       Volvo         S90 T8 PHEV
# 47  Mitsubishi      Outlander PHEV
# 48         Kia           Niro PHEV
# 49    Mercedes            GLC 350e
# 50      Jaguar              I-Pace
# 51     Hyundai          IONIQ PHEV
# 52     Hyundai       Kona Electric
# 53        Audi              e-tron
# 54      Subaru    Crosstrek Hybrid
# 55         Kia             Niro EV
# 56     Porsche              Taycan
#
#                                                  Logo  janv-12  Feb 2012  \
# 0   https://www.carlogos.org/logo/Chevrolet-logo-2...    603.0    1626.0
# 1   https://www.carlogos.org/logo/Toyota-logo-1989...      0.0      21.0
# 2   https://www.carlogos.org/logo/Nissan-logo-2013...    676.0    1154.0
# 3   https://www.carlogos.org/logo/Tesla-logo-2003-...      0.0       NaN
# 4   https://www.carlogos.org/logo/Ford-logo-2003-1...      0.0       NaN
# 5   https://www.carlogos.org/logo/Ford-logo-2003-1...      2.0       2.0
# 6   https://www.carlogos.org/logo/Mitsubishi-logo-...     36.0      80.0
# 7   https://www.carlogos.org/logo/Toyota-logo-1989...      0.0       NaN
# 8   https://www.carlogos.org/logo/Honda-logo-1920x...      0.0       NaN
# 9   https://www.carlogos.org/logo/Ford-logo-2003-1...      0.0       NaN
# 10  https://www.carlogos.org/logo/Fiat-logo-2006-1...      0.0       NaN
# 11  https://www.carlogos.org/logo/Smart-logo-1994-...      0.0       NaN
# 12  https://www.carlogos.org/logo/Chevrolet-logo-2...      NaN       NaN
# 13  https://www.carlogos.org/logo/Honda-logo-1920x...      NaN       NaN
# 14  https://www.carlogos.org/logo/Porsche-logo-200...      NaN       NaN
# 15  https://www.carlogos.org/logo/Cadillac-logo-20...      NaN       NaN
# 16  https://www.carlogos.org/logo/BMW-logo-2000-20...      NaN       NaN
# 17  https://www.carlogos.org/logo/Mercedes-Benz-lo...      NaN       NaN
# 18  https://www.carlogos.org/logo/BMW-logo-2000-20...      NaN       NaN
# 19  https://www.carlogos.org/logo/Kia-logo-2560x14...      NaN       NaN
# 20  https://www.carlogos.org/logo/Volkswagen-logo-...      NaN       NaN
# 21  https://www.carlogos.org/logo/Porsche-logo-200...      NaN       NaN
# 22  https://www.carlogos.org/logo/BMW-logo-2000-20...      NaN       NaN
# 23  https://www.carlogos.org/logo/Tesla-logo-2003-...      NaN       NaN
# 24  https://www.carlogos.org/logo/Porsche-logo-200...      NaN       NaN
# 25  https://www.carlogos.org/logo/Hyundai-logo-sil...      NaN       NaN
# 26  https://www.carlogos.org/logo/Mercedes-Benz-lo...      NaN       NaN
# 27  https://www.carlogos.org/logo/Volvo-logo-2014-...      NaN       NaN
# 28  https://www.carlogos.org/logo/Audi-logo-2009-1...      NaN       NaN
# 29                                                NaN      NaN       NaN
# 30  https://www.carlogos.org/logo/Toyota-logo-1989...      NaN       NaN
# 31  https://www.carlogos.org/logo/BMW-logo-2000-20...      NaN       NaN
# 32  https://www.carlogos.org/logo/Chevrolet-logo-2...      NaN       NaN
# 33  https://www.carlogos.org/logo/Mercedes-Benz-lo...      NaN       NaN
# 34  https://www.carlogos.org/logo/Mercedes-Benz-lo...      NaN       NaN
# 35  https://www.carlogos.org/logo/BMW-logo-2000-20...      NaN       NaN
# 36  https://www.carlogos.org/logo/Chrysler-logo-20...      NaN       NaN
# 37  https://www.carlogos.org/logo/BMW-logo-2000-20...      NaN       NaN
# 38  https://www.carlogos.org/logo/Tesla-logo-2003-...      NaN       NaN
# 39  https://www.carlogos.org/logo/Kia-logo-2560x14...      NaN       NaN
# 40  https://www.carlogos.org/logo/Honda-logo-1920x...      NaN       NaN
# 41  https://www.carlogos.org/logo/Honda-logo-1920x...      NaN       NaN
# 42  https://www.carlogos.org/logo/Volvo-logo-2014-...      NaN       NaN
# 43  https://www.carlogos.org/logo/Mini-logo-2001-1...      NaN       NaN
# 44  https://www.carlogos.org/logo/Hyundai-logo-sil...      NaN       NaN
# 45  https://www.carlogos.org/logo/Cadillac-logo-20...      NaN       NaN
# 46  https://www.carlogos.org/logo/Volvo-logo-2014-...      NaN       NaN
# 47  https://www.carlogos.org/logo/Mitsubishi-logo-...      NaN       NaN
# 48  https://www.carlogos.org/logo/Kia-logo-2560x14...      NaN       NaN
# 49  https://www.carlogos.org/logo/Mercedes-Benz-lo...      NaN       NaN
# 50  https://www.carlogos.org/logo/Jaguar-logo-2012...      NaN       NaN
# 51  https://www.carlogos.org/logo/Hyundai-logo-sil...      NaN       NaN
# 52  https://www.carlogos.org/logo/Hyundai-logo-sil...      NaN       NaN
# 53  https://www.carlogos.org/logo/Audi-logo-2009-1...      NaN       NaN
# 54  https://www.carlogos.org/logo/Subaru-logo-2003...      NaN       NaN
# 55  https://www.carlogos.org/logo/Kia-logo-2560x14...      NaN       NaN
# 56  https://www.carlogos.org/logo/Porsche-logo-200...      NaN       NaN
#
#     mars-12  Apr 2012  May 2012  juin-12  juil-12  ...   mars-19  Apr 2019  \
# 0    3915.0    5377.0    7057.0   8817.0  10666.0  ...  146667.0  147072.0
# 1     912.0    2566.0    3652.0   4347.0   5035.0  ...   42345.0   42345.0
# 2    1733.0    2103.0    2613.0   3148.0   3543.0  ...  122534.0  123485.0
# 3       NaN       NaN       NaN     12.0     31.0  ...  147517.0  148342.0
# 4       NaN       NaN       NaN      NaN      NaN  ...   42231.0   42231.0
# 5       2.0       2.0       8.0     97.0    135.0  ...    9242.0    9242.0
# 6     136.0     215.0     300.0    333.0    366.0  ...    2028.0    2028.0
# 7       NaN       NaN       NaN      NaN      NaN  ...    2472.0    2472.0
# 8       NaN       NaN       NaN      NaN      7.0  ...    1069.0    1069.0
# 9       NaN       NaN       NaN      NaN      NaN  ...   62774.0   63359.0
# 10      NaN       NaN       NaN      NaN      NaN  ...   26788.0   26808.0
# 11      NaN       NaN       NaN      NaN      NaN  ...    7555.0    7640.0
# 12      NaN       NaN       NaN      NaN      NaN  ...    7369.0    7369.0
# 13      NaN       NaN       NaN      NaN      NaN  ...    1039.0    1039.0
# 14      NaN       NaN       NaN      NaN      NaN  ...    4324.0    4479.0
# 15      NaN       NaN       NaN      NaN      NaN  ...    2891.0    2891.0
# 16      NaN       NaN       NaN      NaN      NaN  ...   38098.0   38429.0
# 17      NaN       NaN       NaN      NaN      NaN  ...    4194.0    4195.0
# 18      NaN       NaN       NaN      NaN      NaN  ...    5835.0    5922.0
# 19      NaN       NaN       NaN      NaN      NaN  ...    6396.0    6396.0
# 20      NaN       NaN       NaN      NaN      NaN  ...   14277.0   14677.0
# 21      NaN       NaN       NaN      NaN      NaN  ...    6185.0    6255.0
# 22      NaN       NaN       NaN      NaN      NaN  ...   16805.0   16814.0
# 23      NaN       NaN       NaN      NaN      NaN  ...   69702.0   70752.0
# 24      NaN       NaN       NaN      NaN      NaN  ...     203.0     203.0
# 25      NaN       NaN       NaN      NaN      NaN  ...    6332.0    6378.0
# 26      NaN       NaN       NaN      NaN      NaN  ...    1470.0    1505.0
# 27      NaN       NaN       NaN      NaN      NaN  ...    6039.0    6139.0
# 28      NaN       NaN       NaN      NaN      NaN  ...   10233.0   10240.0
# 29      NaN       NaN       NaN      NaN      NaN  ...      35.0      35.0
# 30      NaN       NaN       NaN      NaN      NaN  ...   55101.0   56500.0
# 31      NaN       NaN       NaN      NaN      NaN  ...    8187.0    8240.0
# 32      NaN       NaN       NaN      NaN      NaN  ...   46211.0   47121.0
# 33      NaN       NaN       NaN      NaN      NaN  ...    1957.0    2107.0
# 34      NaN       NaN       NaN      NaN      NaN  ...    3129.0    3302.0
# 35      NaN       NaN       NaN      NaN      NaN  ...    1104.0    1112.0
# 36      NaN       NaN       NaN      NaN      NaN  ...   13067.0   13414.0
# 37      NaN       NaN       NaN      NaN      NaN  ...   13662.0   14078.0
# 38      NaN       NaN       NaN      NaN      NaN  ...  163971.0  174021.0
# 39      NaN       NaN       NaN      NaN      NaN  ...    2526.0    2531.0
# 40      NaN       NaN       NaN      NaN      NaN  ...    2307.0    2395.0
# 41      NaN       NaN       NaN      NaN      NaN  ...   23221.0   24202.0
# 42      NaN       NaN       NaN      NaN      NaN  ...    3113.0    3198.0
# 43      NaN       NaN       NaN      NaN      NaN  ...    2197.0    2234.0
# 44      NaN       NaN       NaN      NaN      NaN  ...     871.0     880.0
# 45      NaN       NaN       NaN      NaN      NaN  ...     450.0     452.0
# 46      NaN       NaN       NaN      NaN      NaN  ...     689.0     724.0
# 47      NaN       NaN       NaN      NaN      NaN  ...    4896.0    5059.0
# 48      NaN       NaN       NaN      NaN      NaN  ...    4403.0    4648.0
# 49      NaN       NaN       NaN      NaN      NaN  ...     888.0    1108.0
# 50      NaN       NaN       NaN      NaN      NaN  ...    1001.0    1238.0
# 51      NaN       NaN       NaN      NaN      NaN  ...    1811.0    1874.0
# 52      NaN       NaN       NaN      NaN      NaN  ...     143.0     220.0
# 53      NaN       NaN       NaN      NaN      NaN  ...       NaN     253.0
# 54      NaN       NaN       NaN      NaN      NaN  ...      79.0     126.0
# 55      NaN       NaN       NaN      NaN      NaN  ...       NaN      40.0
# 56      NaN       NaN       NaN      NaN      NaN  ...       NaN       NaN
#
#     May 2019  juin-19  juil-19  Aug 2019  sept-19   oct-19   nov-19  Dec 2019
# 0     147,48  147,813  148,063   148,337  148,687  148,757  148,907   149,057
# 1      42345    42345    42345     42345    42345    42345    42345     42345
# 2    124,701  125,857  126,795   127,912   128,96  129,847  130,987   132,214
# 3    149,367  151,117  152,092   153,142  154,242  154,992  156,492   157,992
# 4      42231    42231    42231     42231    42231    42231    42231     42231
# 5       9242     9242     9242      9242     9242     9242     9242      9242
# 6       2028     2028     2028      2028     2028     2028     2028      2028
# 7       2472     2472     2472      2472     2472     2472     2472      2472
# 8       1069     1069     1069      1069     1069     1069     1069      1069
# 9     63,964   64,639   65,359    65,979   66,679  67,279‬   67,879    68,557
# 10    26,868   26,893   26,933    26,978   27,018  27,068‬   27,118    27,211
# 11     7,746     7,82    7,876      7,95    8,004    8,004    8,004     8,004
# 12      7369     7369     7369      7369     7369     7369     7369      7369
# 13      1039     1039     1039      1039     1039     1039     1039      1039
# 14     4,649    4,844    5,009     5,174    5,349   5,522‬   5,695‬     5,879
# 15      2891     2891     2891      2891     2891     2891     2891      2891
# 16    38,868   39,341   39,645     40,03   40,497   40,856   41,774    41,988
# 17      4195     4197     4198      4199     4199     4200     4200      4200
# 18     6,067    6,347    6,448     6,538    6,606     6,67    6,725     6,776
# 19      6397     6397     6398    6,406‬    6,471    6,476    6,479      6,48
# 20    14,941   15,307   15,767    16,456    17,01   17,647   18,013    18,277
# 21      6,36    6,435     6,53      6,63    6,735   6,835‬     6,94      7,05
# 22    16,818   16,826    16,83    16,832   16,833   16,835   16,836    16,837
# 23    72,127   74,852   76,077    77,902   79,577   81,077   83,077    85,077
# 24       203      203      203       203      203      203      203       203
# 25     6,418    6,448    6,483     6,523    6,568   6,614‬   6,659‬    6,713‬
# 26     1,556    1,616    1,666      1,69    1,706   1,759‬   1,784‬     1,801
# 27     6,259    6,429    6,539     6,664    6,839    6,839    6,839     6,839
# 28     10240    10240    10240     10240    10240    10240    10240     10240
# 29        35       35       35        35       35       35       35        35
# 30    58,414   59,558   62,508    65,008   66,658  68,976‬  71,766‬   74,583‬
# 31     8,267    8,292    8,308     8,313    8,315     8,32     8326      8330
# 32    48,517   50,176   51,161    52,881   55,006   56,313   57,313    58,313
# 33     2,292    2,472    2,642     2,747    2,812   2,991‬    3,101    3,169‬
# 34     3,517    3,752    3,982     4,172    4,302   4,544‬   4,744‬     4,881
# 35     1,124     1,13    1,132      1,14    1,145    1,149    1,153     1,156
# 36    13,804   14,195    14,58    14,975    15,39    15,99    16,59    17,382
# 37    14,805   15,713   16,157    16,763   17,073   17,378  17,799‬   18,298‬
# 38   187,971  209,196  221,746   234,096  253,196  270,471  285,471   300,471
# 39      2531    2,582    2,617     2,652    2,702   2,738‬   2,770‬    2,812‬
# 40     2,477    2,529    2,576     2,641    2,676    2,711    2,766     2,811
# 41    25,018   26,048   26,848    27,688   28,088   28,683   29,478    30,233
# 42     3,293    3,468    3,608     3,713    3,893    3,893    3,893     3,893
# 43     2,319    2,363    2,403     2,453    2,483   2,508‬   2,543‬    2,563‬
# 44       941    1,003    1,058     1,098    1,168    9,629    9,723    9,796‬
# 45       452      454      456       458      461      461      461       461
# 46       774      814      859       914      974      988     1001      1010
# 47     5,291    5,513    5,726     6,003    6,179    6,434    6,806     7,075
# 48     4,977    5,328    5,653     5,953    6,328   6,636‬   6,961‬    7,270‬
# 49     1,372    1,642    1,907     2,137    2,317    2,595    2,837     3,026
# 50     1,466    1,702    1,915     2,075    2,235    2,541    2,811     2,987
# 51     1,937    2,089    2,194     2,319    2,454   2,827‬   3,043‬     3,211
# 52       311      427      577       707      897    1,068   1,254‬     1,461
# 53     1,109    1,835    2,513     3,106     3,54    4,002    4,623     5,369
# 54       191     261‬      376       466      586     721‬      842      970‬
# 55       159      208      288       343      433     622‬     880‬     1,166
# 56       NaN      NaN      NaN       NaN      NaN      NaN      NaN       130
#
# [57 rows x 99 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1540624467.py in <cell line: 0>()
#       9 print(df)
#      10
# ---> 11 brand_total_price = df.groupby('brand')['price'].sum().reset_index()
#      12 plt.figure(figsize=(18, 12))
#      13 squarify.plot(sizes=brand_total_price['price'], label=brand_total_price['brand'], alpha=0.4)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'brand'
